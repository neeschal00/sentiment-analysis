# %%
import pandas as pd
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 10)

# %%
import numpy as np

# %%
import re

# %%
import matplotlib as plt

# %%
df = pd.read_csv("rotten_reviews.csv")

# %%
df
# Out:
#         rotten_tomatoes_link        critic_name  top_critic  \
# 0                  m/0814255    Andrew L. Urban       False
# 1                  m/0814255      Louise Keller       False
# 2                  m/0814255                NaN       False
# 3                  m/0814255       Ben McEachen       False
# 4                  m/0814255        Ethan Alter        True
# ...                      ...                ...         ...
# 1130012          m/zulu_dawn      Chuck O'Leary       False
# 1130013          m/zulu_dawn          Ken Hanke       False
# 1130014          m/zulu_dawn    Dennis Schwartz       False
# 1130015          m/zulu_dawn  Christopher Lloyd       False
# 1130016          m/zulu_dawn     Brent McKnight       False
#
#                           publisher_name review_type review_score review_date  \
# 0                         Urban Cinefile       Fresh          NaN  2010-02-06
# 1                         Urban Cinefile       Fresh          NaN  2010-02-06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130017 entries, 0 to 1130016
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   rotten_tomatoes_link  1130017 non-null  object
#  1   critic_name           1111488 non-null  object
#  2   top_critic            1130017 non-null  bool
#  3   publisher_name        1130017 non-null  object
#  4   review_type           1130017 non-null  object
#  5   review_score          824081 non-null   object
#  6   review_date           1130017 non-null  object
#  7   review_content        1064211 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 61.4+ MB

# %%
df.describe()
# Out:
#                      rotten_tomatoes_link   critic_name top_critic  \
# count                             1130017       1111488    1130017
# unique                              17712         11108          2
# top     m/star_wars_the_rise_of_skywalker  Emanuel Levy      False
# freq                                  992          8173     841481
#
#         publisher_name review_type review_score review_date  \
# count          1130017     1130017       824081     1130017
# unique            2230           2          814        8015
# top     New York Times       Fresh          3/5  2000-01-01
# freq             13293      720210        90273       48019
#
#                  review_content
# count                   1064211
# unique                   949181
# top     Parental Content Review
# freq                        267

# %%
df.dtypes
# Out:
# rotten_tomatoes_link    object
# critic_name             object
# top_critic                bool
# publisher_name          object
# review_type             object
# review_score            object
# review_date             object
# review_content          object
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df.head(50)
# Out:
#    rotten_tomatoes_link          critic_name  top_critic  \
# 3             m/0814255         Ben McEachen       False
# 6             m/0814255         Nick Schager       False
# 7             m/0814255     Bill Goodykoontz        True
# 8             m/0814255       Jordan Hoffman       False
# 9             m/0814255         Jim Schembri        True
# 10            m/0814255           Mark Adams       False
# 11            m/0814255          Roger Moore        True
# 12            m/0814255        David Jenkins        True
# 13            m/0814255         Joshua Tyler       False
# 14            m/0814255          Peter Paras       False
# 15            m/0814255        Vic Holtreman       False
# 17            m/0814255          Mark Dujsik       False
# 18            m/0814255           Nell Minow       False
# 20            m/0814255        Dustin Putman       False
# 21            m/0814255       Stephen Holden        True
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 D,D
#
# NameError: name 'D' is not defined

# %%
new_df = df[~df.review_score.str.match('\d\/\d+\/\d{4}')].copy(deep=True)

# %%
new_df.describe()
# Out:
#                      rotten_tomatoes_link      critic_name top_critic  \
# count                              752734           752734     752734
# unique                              17620             6841          2
# top     m/star_wars_the_rise_of_skywalker  Dennis Schwartz      False
# freq                                  672             6488     575273
#
#          publisher_name review_type review_score review_date  \
# count            752734      752734       752734      752734
# unique             1626           2          812        7455
# top     eFilmCritic.com       Fresh          3/5  2000-01-01
# freq               8550      480102        76232       22100
#
#                               review_content
# count                                 752734
# unique                                671864
# top     full review at Movies for the Masses
# freq                                     199

# %%
new_df.dtypes['review_score']
# Out:
# dtype('O')
